# %%
import pandas as pd
import numpy as np

# %%
cancer = pd.read_csv("G:\PythonCode\AIML Community\Breast-Cancer-Detection-using-Machine-Learning-master\Breast-Cancer-Detection-using-Machine-Learning-master\cancer dataset.csv")

# %%
#Get first 5 rows
cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#Statistical parameter
cancer.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
#Shape of the dataset
cancer.shape
# Out:
# (569, 32)

# %%
#Missing values of dataset
cancer.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
# Find the value count of B(Benign) and M(Malignant) cancer cells in the column "diagnosis"

cancer['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
#Creating a pairplot and mention the findings

import seaborn as sns

# %%
pp = cancer.iloc[ : ,:5]
sns.heatmap(pp.corr(), annot=True, fmt="0.0%" )

# %%
sns.pairplot(pp)

# %%
#The conclusion that can be drawn from the above Pair plot demonstrates as follows:
#--> 1.The ID is not having any relation with the rest of the dataset and it can be interpreted from the graph due to abrupt distribution
#--> 2.Radius_Mean is forming a scattered orientation with texture_mean as the texture belongs to the same cluster despite of different 
# radius value. From the Heat Map we can determine that the texture_mean is only 32% correlated with the radius_mean value
#--> 3.The perimeter_mean is  totally dependent on the radius_mean value as we all know that perimeter is directly proportional to
# to the radius value. Hence in Heat map, we can find 100% dependency between them. As the correlation is positive so we can find
# that with the increase of radius_mean value, the perimeter_mean also increases proportionally and formes a Straight Line

# %%
correlation = cancer.corr()
correlation
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
#Create a correlation matrix and mention strongly, weakly and negatively correlated quantities.

sns.heatmap(correlation)
